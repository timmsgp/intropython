# %% [markdown]
# # Welcome to Session 5 - Searching for Data in Data Structures and Matching Patterns in Data

# %% [markdown]
# Testing for the presence of data within a data object is an important skill. This is accomplished in a few key ways:
# 1) Test to see if a match exists within a simple object like a string, integer, etc.
# 2) Test to see if a match exists within a data structure like a list or dictionary.
# 3) Test to see if complex patterns exist within data, using Regular Expressions.

# %% [markdown]
# ## The 'In' Operator

# %% [raw]
# We already looked at some simple operators used to test conditions (==, !-, <, >). These are usually used in conditional statements (if...elif...else).
#
# The 'in' operator tests for membership, i.e. "is 'drum' in 'Red drum'?" and it returns True or False.

# %% [markdown]
# ### Test for a Match in a String

# %%
def testMembership(mydata,teststring):
    if teststring in mydata:
        print('found it!')
    else:
        print('didn\'t find it') # Note: If I want to use an apostrophe in my text, I must "escape" it with \.


mytext = 'The most beautful inshore fish is the Red drum.'

testMembership(mytext,'drum')
testMembership(mytext,'bass')
# Out:
# found it!
# didn't find it

# %% [markdown]
# ### Test for a Match in a list

# %%
# Same function as above

def testMembership(mydata,teststring):
    if teststring in mydata:
        print('found it!')
    else:
        print('didn\'t find it')
        
mytext = ['The most beautful inshore fish is the Red drum.','Sheepshead is cool looking though!','I\'ll always be glad to see a Black seabass though.']

testMembership(mytext,'drum')
testMembership(mytext,'bass')
# Out:
# didn't find it
# didn't find it

# %% [markdown]
# #### Question 1

# %% [markdown]
# What happened?

# %%
# Try this

def testMembership(mydata,teststring):
    if teststring in mydata:
        print('found it!')
    else:
        print('didn\'t find it')
        
mytext = ['The most beautful inshore fish is the Red drum.','Sheepshead is cool looking though!','I\'ll always be glad to see a Black seabass though.','drum','bass']

testMembership(mytext,'drum')
testMembership(mytext,'bass')
# Out:
# found it!
# found it!

# %% [markdown]
# When testing for membership in a data structure, the 'in' operator is looking for the test string AS a member.
# 1) The members of the list we used are themselves strings
# 2) If we want to search within those strings, we need to crete a loop to do so.

# %% [markdown]
# #### Activity 1

# %% [markdown]
# Using the code below, introduce a for loop within the testMembership function to test for the presence of our test string in the text.

# %%
def testMembership(mydata,teststring):
    if teststring in mydata:
        print('found it!')
    else:
        print('didn\'t find it')
        
mytext = ['The most beautful inshore fish is the Red drum.','Sheepshead is cool looking though!','I\'ll always be glad to see a Black seabass though.']

testMembership(mytext,'drum')
testMembership(mytext,'bass')

# %% [markdown]
# ### Test for a Match in a Dictionary

# %% [markdown]
# ***Consistent Subsection Types***

# %% [markdown]
# ### [Subsection topic]

# %% [markdown]
# Subsection textual content cells as needed

# %%
#Subsection code content cells as needed

# %% [markdown]
# ### Question [n]

# %% [markdown]
# Question content [question is to reflect on theory just learned]

# %%
#Answer walkthrough is executable code

# %% [markdown]
# ### Activity [n]

# %% [markdown]
# Activity description/task [activity is to exercise theory just learned]

# %%
#Tackle Activity [n] here [code space]

# %% [markdown]
# ### Quiz

# %% [markdown]
# [hyperlink to a quiz here. Perhaps we can use Google Forms quizzes with multi-choice questions to help solidify learning]

# %% [markdown]
# ### Challenge [this is homework or to do if the class finishes early]

# %% [markdown]
# Challenge description [challenge is to consolidate and practice content learned during this session]

# %%
#Tackle the challenge here [code space]

# %% [markdown]
# ### Resources [web resources for reference or reading to help expand knowledge on this section's content]
